# %%
import os
import rootpath
import sys
sys.path.append(rootpath.detect())

import numpy as np
import matplotlib.pyplot as plt
import json

from testsuite.results import ResultsContainer

# %%
def load_file(file_name):
    return ResultsContainer(os.path.join(processed_results_dir, file_name))

# %%
processed_results_dir = "../processed_results_5sample"
processed_files = list(sorted(os.listdir(processed_results_dir)))

# %%
problems = set([p.split("__")[0] for p in processed_files])

# %%
a = load_file(processed_files[47])
fig0 = a.plot_hpv()
a.plot_hpv(reference=True, axis=fig0.gca(), c="C3")
print(f"WFG{a.n_prob[0]} {a.n_obj[0]}obj {a.n_dim[0]}dim")

fig1 = plt.figure(figsize=[8,8])
ax1 = fig1.gca()
for r0 in a.results:
    r0.plot_front(axis=ax1, c="C0")
for r1 in a.reference:
    r1.plot_front(axis=ax1, c="C3")
ax1.scatter(*np.asarray(r0.targets).T, c="magenta", s=20)
# Out:
# WFG3 3obj 10dim
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-131fd18336a3> in <module>
#      10 for r1 in a.reference:
#      11     r1.plot_front(axis=ax1, c="C3")
# ---> 12 ax1.scatter(*np.asarray(r0.targets).T, c="magenta", plot_kwargs={'s':20})
#
# ~/miniconda3/envs/testsuite/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/envs/testsuite/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/miniconda3/envs/testsuite/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4496                 )
#    4497         collection.set_transform(mtransforms.IdentityTransform())
# -> 4498         collection.update(kwargs)
#    4499
#    4500         if colors is None:
#
# ~/miniconda3/envs/testsuite/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'PathCollection' object has no property 'plot_kwargs'

# %%
np.asarray(r.targets)
# Out:
# array(None, dtype=object)
