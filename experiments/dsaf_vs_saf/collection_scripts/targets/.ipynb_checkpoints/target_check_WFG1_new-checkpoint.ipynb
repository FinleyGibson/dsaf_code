# %%
import os
import sys
import rootpath
sys.path.append(rootpath.detect())

from testsuite.utilities import Pareto_split, dominates
from testsuite.analysis import load_all #, plot_all_pareto_2d, PLOT_STYLE, plot_measure
from json import load

import pickle
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import wfg

# %%
M = 2                                   # Number of objectives
kfactor = 1
lfactor = 2
k = kfactor*(M-1)   # position related params
l = lfactor*2           # distance related params

n_dim = k+l
n_obj = M
func = wfg.WFG5

# %%
N = 500
y = np.zeros((N, n_obj))
x = np.zeros((N, n_dim))
for n in range(N):
    z = wfg.random_soln(k, l, func.__name__)
    y[n,:] = func(z, k, M)
    x[n,:] = z

# %%
with open("./targets", "r") as infile:
    target_dict = load(infile)

# %%
targets = np.asarray(target_dict['ELIPSOIDE_2obj'])

# %%
plt.figure(figsize=[10, 10])
plt.scatter(*y.T, s=2)
plt.scatter(*targets.T, c="magenta")
plt.gca().axis("scaled")
# plt.scatter(*targets2.T, c="cyan")
# Out:
# (0.06009504777350973, 2.19085261677269, -0.1974605245060621, 4.186956372464104)

# %%
p2 = np.load("../../../undirected/igd_refpoints/problem_refpoints/data/wfg_elipse_2d_refpoints")
p2 = p2[::20]
p2.shape
# Out:
# (250, 2)

# %%
from testsuite.utilities import get_target_igd_refpoints

# %%
# dom_inds = [dominates(targets[1:2], pi, maximize= False) for pi in p2]

# %%
axes.flatten()
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig, axes = plt.subplots(1, 6,figsize=[15, 10])

target = targets[2]

for ax, target in zip(axes.flat, targets):
    igd_points, other_points = get_target_igd_refpoints(target, p2) 
    
    ax.scatter(*other_points.T, c="C0", s=2, alpha=0.2)
    ax.scatter(*igd_points.T, c="C1", s=2)
    ax.scatter(*target.T, c="magenta", s=10)
    ax.axis('scaled')
