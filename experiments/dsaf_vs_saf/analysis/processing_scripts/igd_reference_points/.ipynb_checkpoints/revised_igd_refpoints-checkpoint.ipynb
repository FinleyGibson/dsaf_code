# %%
import os
import sys
import rootpath
sys.path.append(rootpath.detect())
# %config Completer.use_jedi = False

# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
import wfg
from testsuite.analysis_tools import draw_samples, attainment_sample
from testsuite.utilities import KDTree_distance
from scipy.spatial import distance_matrix

# %%
ref_path  = os.path.join(rootpath.detect(), 'experiments/directed/analysis/processing_scripts/igd_reference_points/reference_points')
assert os.path.isfile(ref_path)

with open(ref_path, "r") as infile:
    REF_POINTS = json.load(infile)

# %%
func = wfg.WFG4

samples_x, samples_y = draw_samples(func, 4, 5, 1000000)
# Out:
# 100%|██████████| 1000000/1000000 [00:07<00:00, 131784.75it/s]

# %%
p = np.asarray(REF_POINTS["wfg4_4obj_8dim"])

plt.scatter(*p[:, :2].T)
plt.scatter(*samples_y[:,:2].T, s=2, c="C1")

# %%
ans = attainment_sample(samples_y, 800)
# Out:
# 100%|██████████| 800/800 [13:41<00:00,  1.03s/it]

# %%
plt.figure()
plt.scatter(*p[:, :2].T)
plt.scatter(*samples_y[:,:2].T, s=2, c="C1")
plt.scatter(*ans[:,:2].T, s=2, c="C3")

# %%
synthetic_samples = np.random.multivariate_normal(np.zeros(4), np.eye(4), 1000000)
synthetic_samples.shape
# Out:
# (1000000, 4)

# %%
np.std(samples_y, axis=0)
# Out:
# array([0.29647495, 0.7751475 , 1.63710806, 1.9736644 ])

# %%
func = wfg.WFG4

p = np.asarray(REF_POINTS["wfg4_3obj_8dim"])

# %%
samples_x, samples_y = draw_samples(func, 3, 4, 1000000)
# Out:
# 100%|██████████| 1000000/1000000 [00:05<00:00, 185013.97it/s]

# %%
attain_s = attainment_sample(samples_y, 800)
# Out:
# 100%|██████████| 800/800 [12:39<00:00,  1.05it/s]

# %%
sample_attainment_nnds = KDTree_distance(samples_y, attain_s)
sample_attainment_nnds.shape
# Out:
# (800,)

# %%
sample_attainment_nnds.max()
# Out:
# 1.3191568191972098

# %%
# %matplotlib qt

# %%
fig = plt.figure(figsize=[10, 10])
ax = fig.gca(projection="3d")

# ax.scatter(*p.T, c="C0", alpha=0.1, s=50)
# ax.scatter(*samples_y[::100].T, c="C1", s=5)
ax.scatter(*attain_s[sample_attainment_nnds<.1].T, c="C3", s=5)
# ax.scatter(*attain_s[sample_attainment_nnds>.1].T, c="C2", s=2)

# %%
fig = plt.figure()
ax = fig.gca()
aa = ax.hist(sample_attainment_nnds, int(len(sample_attainment_nnds)/10))
ax.axvline(0.1, c="C3")
ax.axvline(ab, c="C3")

# %%
ab = aa[1][np.where(aa[0][:-1]-aa[0][1:]<0)[0][0]-1]

# %%
fig = plt.figure(figsize=[10, 10])
ax = fig.gca()

# ax.scatter(*p[:,:2].T, c="C0", alpha=0.3, s=50)
# ax.scatter(*samples_y[:,:2][::100].T, c="C1", s=5)
ax.scatter(*attain_s[sample_attainment_nnds<ab][:,:2].T, c="C3", s=2)
fig

# %%
func = wfg.WFG4

p = np.asarray(REF_POINTS["wfg4_4obj_8dim"])

# %%
samples_x, samples_y = draw_samples(func, 4, 5, 1000000)
# Out:
# 100%|██████████| 1000000/1000000 [00:05<00:00, 181948.05it/s]

# %%
attain_s = attainment_sample(samples_y, 800)
# Out:
#   1%|          | 6/800 [00:06<14:58,  1.13s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-941e6e5e514c> in <module>
# ----> 1 attain_s = attainment_sample(samples_y, 800)
#
# ~/phd/code/testsuite/testsuite/analysis_tools.py in attainment_sample(Y, n_samples)
#     338             mid = (lo + hi) // 2
#     339             v[m] = Ys[mid, m]
# --> 340             if not any(weak_dominates(Y, v)):
#     341                 lo = mid + 1
#     342             else:
#
# ~/phd/code/testsuite/testsuite/analysis_tools.py in weak_dominates(Y, x)
#     288         1d-array.  The ith element is True if Y[i] weakly dominates x
#     289     """
# --> 290     return (Y <= x).sum(axis=1) == Y.shape[1]
#     291
#     292
#
# ~/miniconda3/envs/testsuite/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
sample_attainment_nnds = KDTree_distance(samples_y, attain_s)
sample_attainment_nnds.shape
# Out:
# (800,)
