# %%
import os
import rootpath
import sys
sys.path.append(rootpath.detect())

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from figure_utilities import RESULT_FILES_LIST_2OBJ, RESULT_FILES_LIST_3OBJ, RESULT_FILES_LIST_4OBJ, load_result, format_figures, Symbols, Styles, save_fig

# %%
format_figures()

# %%
med_result_2d_name = 'wfg6_2obj_6dim_1.json'
med_result_2d = load_result(med_result_2d_name)

med_result_2d_name = 'wfg6_2obj_6dim_3.json'
med_result_2d = load_result(med_result_2d_name)

# %%
def plot_result(ax, x, history, label):
    mu = np.median(history, axis=0)
    lb = np.quantile(history, 0.25, axis=0)
    ub = np.quantile(history, 0.75, axis=0)
    
    ax.fill_between(x, lb, ub, alpha=0.2)
    ax.plot(x, mu, label=label)
    ax.set_xlabel(r"$n$")
    ax.set_ylabel(r"$H_{a}$")
    
    ax.set_xlim([10, 150])

fig0 = plt.figure(figsize=[4, 2])
ax0 = fig0.gca()

plot_result(ax = ax0, x = med_result_2d.dual_hpvref_hist_x, history = med_result_2d.dual_hpv_history[0], label=r"$DSAF$")
plot_result(ax = ax0, x = med_result_2d.dual_hpvref_hist_x, history = med_result_2d.dual_hpvref_history[0], label=r"$SAF$")
ax0.legend()

# save_fig(fig0, filename="median_decay_plot_2obj")

# %%
med_result_3d = load_result("wfg6_3obj_8dim_1.json")

# %%
fig1 = plt.figure(figsize=[4, 2])
ax1 = fig1.gca(sharex = ax0, sharey=ax0)
plot_result(ax = ax1, x = med_result_3d.dual_hpvref_hist_x, history = med_result_3d.dual_hpv_history[0], label=r"$DSAF$")
plot_result(ax = ax1, x = med_result_3d.dual_hpvref_hist_x, history = med_result_3d.dual_hpvref_history[0], label=r"$SAF$")
# ax.set_title(f"WFG{med_result_3d.n_prob} {med_result_3d.n_obj} objective")
ax1.legend()


# save_fig(fig1, filename="median_decay_plot_3obj")
# Out:
# /tmp/ipykernel_473025/479446208.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax1 = fig1.gca(sharex = ax0, sharey=ax0)

# %%
med_result_4d = load_result("wfg6_4obj_10dim_1.json")

# %%
fig2 = plt.figure(figsize=[4, 2])
ax2 = fig2.gca(sharex=ax0, sharey=ax0)
plot_result(ax = ax2, x = med_result_4d.dual_hpvref_hist_x, history = med_result_4d.dual_hpv_history[0], label=r"$DSAF$")
plot_result(ax = ax2, x = med_result_4d.dual_hpvref_hist_x, history = med_result_4d.dual_hpvref_history[0], label=r"$SAF$")
# ax.set_title(f"WFG{med_result_4d.n_prob} {med_result_4d.n_obj} objective")
ax2.legend()

# save_fig(fig2, filename="median_decay_plot_4obj")
# Out:
# /tmp/ipykernel_473025/3357409671.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax2 = fig2.gca(sharex=ax0, sharey=ax0)
